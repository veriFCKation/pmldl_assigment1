# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

import torch
from torch import nn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/filtered.tsv", sep='\t')

# %%
df2 = df[:50000]

# %%
df3.to_csv("raw50K.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   50000 non-null  int64
#  1   reference    50000 non-null  object
#  2   translation  50000 non-null  object
#  3   similarity   50000 non-null  float64
#  4   lenght_diff  50000 non-null  float64
#  5   ref_tox      50000 non-null  float64
#  6   trn_tox      50000 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.7+ MB

# %%
#extract only reference and translation textes
df2 = df.drop(['Unnamed: 0', 'similarity', 'lenght_diff', 'ref_tox', 'trn_tox'], axis=1)
df2.head()
# Out:
#                                            reference  \
# 0  If Alkar is flooding her with psychic waste, t...
# 1                          Now you're getting nasty.
# 2           Well, we could spare your life, for one.
# 3          Ah! Monkey, you've got to snap out of it.
# 4                   I've got orders to put her down.
#
#                                          translation
# 0  if Alkar floods her with her mental waste, it ...
# 1                        you're becoming disgusting.
# 2                      well, we can spare your life.
# 3                       monkey, you have to wake up.
# 4                         I have orders to kill her.

# %%
df2.to_csv('raw_text_50K.csv') #save train dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/filtered.tsv", sep='\t')

# %%
df3 = df[50000:60000]

# %%
df3.to_csv("raw10K.csv")

# %%
df3 = df3.drop(['Unnamed: 0', 'similarity', 'lenght_diff', 'ref_tox', 'trn_tox'], axis=1)

# %%
df3.head()
# Out:
#                                                reference  \
# 50000  If I come to hate you, there won'tbe a single ...
# 50001          "Then you're thinking he might be queer."
# 50002  Mr. LeMoyne, I saw you and Murphy Doucet kill ...
# 50003             Is there anyone I haven't fucked over?
# 50004                            I cleaned up your slop.
#
#                                              translation
# 50000  because if I did, there wouldn't be anyone els...
# 50001                    "you think he's gay after all."
# 50002  I saw you and Murphy's Doucet, kill Dewitt Pre...
# 50003                is there someone I didn't cheat on?
# 50004                             I cleaned up the mess.

# %%
df4 = pd.DataFrame()

# %%
df4['reference'] = df3['reference'].values
df4['translation'] = df3['translation'].values
df4.head()
# Out:
#                                            reference  \
# 0  If I come to hate you, there won'tbe a single ...
# 1          "Then you're thinking he might be queer."
# 2  Mr. LeMoyne, I saw you and Murphy Doucet kill ...
# 3             Is there anyone I haven't fucked over?
# 4                            I cleaned up your slop.
#
#                                          translation
# 0  because if I did, there wouldn't be anyone els...
# 1                    "you think he's gay after all."
# 2  I saw you and Murphy's Doucet, kill Dewitt Pre...
# 3                is there someone I didn't cheat on?
# 4                             I cleaned up the mess.

# %%
df4.to_csv("raw_text_10K.csv")#save test dataset
